# %% [markdown]
# Day 1

# %% [markdown]
# Dataset: Iris Dataset: https://en.wikipedia.org/wiki/Iris_flower_data_set

# %% [markdown]
# Petal and Sepal: http://terpconnect.umd.edu/~petersd/666/html/iris_with_labels.jpg

# %% [markdown]
# For now lets understand Vector as:
#
# n-dimensional Numerical array(Now)
#
# [4.1, 8.7] => This is a 2-dimensional vector or array
#
# What is 1-dimensional vector?
# 1- D vector is nothing but a scalar
#
# x = [4.1]
# x = 4.1

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
iris = pd.read_csv("iris.csv")

# %%
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
iris.shape
# Out:
# (150, 5)

# %%
iris.columns
# Out:
# Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width',
#        'species'],
#       dtype='object')

# %%
# How many data points for each class are present? or How many flowers for each Species are present?

iris["species"].value_counts()
# Out:
# species
# setosa        50
# versicolor    50
# virginica     50
# Name: count, dtype: int64

# %% [markdown]
# Day 2

# %% [markdown]
# An Imbalanced dataset is one where the distribution of the classes is not uniform, meaning that one or more classes have significantly fewer samples compared to the others.

# %% [markdown]
# Day 3

# %% [markdown]
# 2D-Scatter Plot

# %%
iris.plot(kind='scatter', x='sepal_length', y='sepal_width')
plt.show()

# %% [markdown]
# 3D Scatter Plot

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_style("whitegrid")
sns.FacetGrid(iris, hue="species", height=4) \
   .map(plt.scatter, "sepal_length", "sepal_width") \
   .add_legend()

plt.show()

# %% [markdown]
# Using sepal_length and sepal_width features, we can distinguish Setosa flowers from Others.
#
# Separating Versicolor from Verginica is much harder as they have considerable overlap.

# %% [markdown]
# Day 4

# %%
import plotly.express as px
df = px.data.iris()
fig = px.scatter_3d(df, x='sepal_length', y='sepal_width', z='petal_length',
                    color='species')

fig.show()

# %% [markdown]
# Day 5

# %% [markdown]
# Pair-Plots

# %%
plt.close()

sns.set_style("whitegrid")

sns.pairplot(iris, hue="species", height=5)

plt.show()

# %% [markdown]
# Day 6

# %% [markdown]
# Disadvantages of Pair Plot

# %% [markdown]
# Day 7

# %% [markdown]
# Histogram and PDF

# %%
iris_setosa = iris.loc[iris["species"] == "setosa"]
iris_virginica = iris.loc[iris["species"] == "virginica"]
iris_versicolor = iris.loc[iris["species"] == "versicolor"]

plt.plot(iris_setosa["petal_length"], np.zeros_like(iris_setosa["petal_length"]), 'o')
plt.plot(iris_versicolor["petal_length"], np.zeros_like(iris_versicolor["petal_length"]), 'o')
plt.plot(iris_virginica["petal_length"], np.zeros_like(iris_virginica["petal_length"]), 'o')

plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

g = sns.FacetGrid(iris, hue="species", height=5)
g.map(sns.histplot, "petal_length", bins=5, kde=True)
g.add_legend()

plt.show()

# %%
g = sns.FacetGrid(iris, hue="species", height=5)
g.map(sns.kdeplot, "petal_length", fill=True)
g.add_legend()

plt.show()

# %% [markdown]
# Day 8

# %% [markdown]
# Univariate Analysis

# %%
import seaborn as sns
import matplotlib.pyplot as plt

g = sns.FacetGrid(iris, hue="species", height=5)
g.map(sns.histplot, "petal_width", bins=5, kde=True)
g.add_legend()

plt.show()

# %%
g = sns.FacetGrid(iris, hue="species", height=5)
g.map(sns.kdeplot, "petal_width", fill=True)
g.add_legend()

plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

g = sns.FacetGrid(iris, hue="species", height=5)
g.map(sns.histplot, "sepal_length", bins=5, kde=True)
g.add_legend()

plt.show()

# %%
g = sns.FacetGrid(iris, hue="species", height=5)
g.map(sns.kdeplot, "sepal_length", fill=True)
g.add_legend()

plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

g = sns.FacetGrid(iris, hue="species", height=5)
g.map(sns.histplot, "sepal_width", bins=5, kde=True)
g.add_legend()

plt.show()

# %%
g = sns.FacetGrid(iris, hue="species", height=5)
g.map(sns.kdeplot, "sepal_width", fill=True)
g.add_legend()

plt.show()
